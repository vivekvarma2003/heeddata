# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://read_user:heeddata123@mongo6testcluster.h7rii.mongodb.net/?authMechanism=DEFAULT")

# %%
# Filtering Test Case 1: Fetch migration_datetime > '20201224' from 'database_migrations' collection
db = client['insider']
collection = db['database_migrations']
query = {
    'migration_datetime': {'$gt': '20201224'}
}
projection = {'_id': 0, 'migration_datetime': 1}
documents = collection.find(query, projection)

print("Filtering Test Case 1: migration_datetime > '20201224'")
for document in documents:
    print(document)
# Out:
# Filtering Test Case 1: migration_datetime > '20201224'
# {'migration_datetime': '20201224162700'}
# {'migration_datetime': '20210113092600'}
# {'migration_datetime': '20210113092600'}
# {'migration_datetime': '20201224162700'}
# {'migration_datetime': '20201224162700'}
# {'migration_datetime': '20201224162700'}
# {'migration_datetime': '20210113092600'}
# {'migration_datetime': '20210113092600'}

# %%
# Filtering Test Case 2: Fetch object_name and organization_id for evt_class: RESOURCES_DISCOVERED,time greater than  1701438464 } from 'azure_prices' collection
db = client['keeper']
collection = db['event']
query = {
  'evt_class': "RESOURCES_DISCOVERED",
  'time': { '$gt': 1728550672 }
}
projection = {'_id': 0, 'object_name': 1, 'organization_id': 1}
documents = collection.find(query, projection)
for document in documents:
    print(document)
# Out:
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# {'object_name': 'MaxLife-AWS', 'organization_id': '478de11c-c35d-4895-a65c-0a44993d37eb'}
# ...
